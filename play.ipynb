# %%
from train_gpt2 import ShakespeareDataset

dataset = ShakespeareDataset("input.txt", batch_size=4, seq_len=16, world_size=1, rank=1)

# %%
import torch
dataloader = torch.utils.data.DataLoader(dataset)

# %%
for x, y in dataloader:
    print(x.shape)
# Out:
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# torch.Size([1, 4, 16])
# ...
